# %%
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import requests
import pandas as pd
import numpy as np
import time

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):
    try:
        price = soup.select_one("span.a-price > span.a-offscreen")
        if price:
            return price.text.strip()
        return ""
    except:
        return ""


# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"	

    return available

# %%
if __name__ == '__main__':

    # add your user agent 
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    URL = "https://www.amazon.in/s?k=laptop&i=electronics&crid=1MGERN7C6LYFR&sprefix=lap%2Celectronics%2C669&ref=nb_sb_noss_1"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[], "reviews":[],"availability":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        product_url = urljoin("https://www.amazon.in", link)
        product_url = product_url.split("/ref=")[0] # clean URL
        
        new_webpage = requests.get(product_url, headers=HEADERS)
        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))

        time.sleep(2)   # prevent blocking

    
    amazon_df = pd.DataFrame.from_dict(d)
    # ---------- CLEANING ----------

    amazon_df['title'] = amazon_df['title'].replace('', np.nan)

    amazon_df['price'] = (
        amazon_df['price']
        .str.replace('â‚¹', '₹', regex=False)
        .str.replace(',', '', regex=False)
    )

    amazon_df['price'] = amazon_df['price'].apply(
        lambda x: f"₹{float(x.replace('₹','')):,.2f}" if x else x
    )

    amazon_df['reviews'] = (
        amazon_df['reviews']
        .str.replace(',', '', regex=False)
        .str.replace('-', '', regex=False)
    )

    amazon_df['rating'] = (
        amazon_df['rating']
        .str.replace(' out of 5 stars', '', regex=False)
    )

    amazon_df = amazon_df.dropna(subset=['title'])

    # save CSV (₹ symbol safe for Excel)
    amazon_df.to_csv("amazon_data.csv", index=False, encoding="utf-8-sig")

# %%
d
# Out:
# {'title': ['Lenovo V14 Intel Core i3 13th Gen 14" FHD (1920x1080) Antiglare 250 Nits Thin and Light Laptop (8GB RAM/512GB SSD/Windows 11 Home/Office Home 2024/Iron Grey/1.43 kg), 83A0A0PBIN',
#   'Lenovo V15 G4 AMD Ryzen 5 7520U 15.6 inch FHD Laptop, AMD Graphics, 16GB DDR5 5500Mhz Ram, 512GB SSD NVMe, Windows 11, Dolby Audio, Arctic Grey, 1 Year Onsite Brand Warranty',
#   'BrowseBook 14.1" FHD IPS Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB RAM | 128GB SSD | Windows 11 | 38Wh | 1.3kg | Grey',
#   'acer Aspire Lite, AMD Ryzen 3 5300U Processor, 16 GB RAM, 512GB SSD, Full HD, 15.6"/39.62cm, Windows 11 Home, Steel Gray, 1.59KG, AL15-41, Metal Body, Premium Thin and Light Laptop',
#   'acer [SmartChoice Aspire 3 Laptop Intel Core Celeron N4500 Processor Laptop (8 GB LPDDR4X SDRAM/512 GB SSD/Win11 Home/38 WHR/HD Webcam) A325-45 with 39.63 cm (15.6") HD Display, Pure Silver, 1.5 KG',
#   'Primebook 2 Max 2025 (New Launch) | 8GB RAM, 256GB UFS Storage | 15.6-Inch Full HD IPS Display | 12hrs Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI | Aqua',
#   'Lenovo Yoga Slim 7 (Smartchoice) Intel Core Ultra 9 185H 14"(35.5cm) WUXGA-OLED Laptop (32GB RAM/1TB SSD/AI PC/Windows 11/Microsoft 365 Basic + Office Home 2024/1Yr ADP Free/Grey/1.39Kg), 83CV00B3IN',
#   'Lenovo Smartchoice Yoga Slim 7 Aura Edition, Intel Core Ultra 7 258V, 47 Tops, Copilot+ AI PC, 32GB RAM, 1TB SSD, 15"(38.86cm), Windows 11, MS Office Home 2024, Grey, 1.53Kg, 83HM004NIN, AI Laptop',
#   'Lenovo ThinkBook 16, AMD Ryzen 7 7735HS, 16GB RAM, 512GB SSD, WUXGA IPS 16", Windows 11 Home, Office 2024, 1.7kg, 21MWA0R4IN, Backlit Keyboard, Fingerprint, 300 Nits, 1Y Warranty, Aluminium Top Laptop',
#   'Primebook 2 Pro 2025 (New Launch) | 8GB RAM, 128GB UFS Storage | 14.1-Inch FHD IPS Display | 14 Hours Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Aqua)',
#   'HP 14s Intel Celeron Dual Core N4500 Laptop (8GB/512GB SSD/Win 11) 14.0" HD Display, MSO 24, Black, 1.46kg, DQ3149TU Thin and Light Business Laptop',
#   'HP 15s, 12th Gen Intel Core i3-1215U (8GB DDR4, 512GB SSD) Anti-Glare, 15.6"/39.6cm,FHD, Win 11, MS Office 21, Silver, 1.69kg, fy5006tu/fd0751tu/fd0752tu, UHD Graphics, HD Camera, Dual Speakers Laptop',
#   "HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fc0500AU, FHD Camera w/Privacy Shutter Laptop",
#   'Dell 15, AMD Ryzen 5-7530U Processor, 16GB RAM, 512GB SSD, FHD IPS 15.6"/39.62 cm 120Hz Display, Windows 11, MSO\'24, Platinum Silver, 1.67kg, Standard Keyboard, 15 Month McAfee, Thin & Light Laptop',
#   'HP 255 G10 Laptop for Home or Work, 16GB RAM DDR5, 512GB SSD, 15.6" Full HD, Ryzen 3 7335U (Beats Intel i5-1135G7), HDMI, USB-C, Windows 11',
#   "HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fd0573TU, FHD Camera w/Shutter Laptop",
#   'Acer Aspire 3, Intel Core Celeron N4500, 12GB LPDDR4 RAM, 512GB SSD, HD, 14"/35.56cm, Windows 11 Home, Silver, 1.3KG, A324-45, Thin and Light Laptop',
#   'Comfyable Laptop Sleeve 13 Inch Precisely Compatible with MacBook Pro M2 2022 M1 2020-2016 & Mac Air M4 A3240 2025 M3 2024 M2 2022 M1 2020, Faux Leather Cover Case, Brown',
#   'Comfyable Laptop Sleeve 13 Inch Precisely Compatible with MacBook Pro M2 2022 M1 2020-2016 & Mac Air M4 A3240 2025 M3 2024 M2 2022 M1 2020, Faux Leather Cover Case, Brown',
#   "HP 15, 13th Gen Intel Core i5-1334U (16GB DDR4, 1TB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365(1yr)* Office24, Silver, 1.59kg, FD0552TU, Iris Xe, FHD Camera w/Shutter, Backlit Laptop",
#   'Lenovo IdeaPad 1 Intel Celeron N4500, 8GB RAM, 512GB SSD, HD 15.6"(39.6cm), Windows 11, Grey, 1.55Kg, 82LX00F7IN, 3 Month Game Pass Laptop',
#   'Dell 15, AMD Ryzen 7-7730U, 16GB DDR4, 512GB SSD, FHD 15.6"/39.6 cm, Windows 11, Office H&S 2024, Platinum Silver, 1.63 Kg, 120Hz 250 nits, AMD Radeon Graphics, Standard Keyboard, Thin & Light Laptop',
#   'Lenovo ThinkBook 16, AMD Ryzen 7 7735HS, 16GB RAM, 512GB SSD, WUXGA IPS 16", Windows 11 Home, 1.7kg, 21MWA0AUIN, Backlit Keyboard, Fingerprint, 300 Nits, 1Y Warranty, Aluminium Top Laptop',
#   'Acer SmartChoice Aspire Lite, AMD Ryzen 5-5625U Processor, 16 GB/512 GB, Full HD, 15.6"/39.62 cm, Windows 11 Home, Steel Gray, 1.59 kg, AL15-41, Metal Body, Thin and Light Laptop',
#   'Primebook 2 Neo 2025 (New Launch) | 6GB RAM, 128GB Storage (Upgradable Upto 512GB) | MediaTek Helio G99 | Android 15 (PrimeOS3.0) | in-Built AI | 11.6” Thin & Light Laptop | Type-C, USB, MicroSD Ports',
#   'Acer Aspire Lite, Intel Core i3 13th Gen - 1305U, 16GB RAM, 512GB SSD, Full HD 15.6"/39.62 cm, Windows 11 Home, Steel Gray, 1.59 KG, AL15-53, Metal Body, 36 WHR, Thin and Light Premium Laptop',
#   'ULTIMUS APEX Laptop Intel Celeron Dual Core 8 GB LPDDR4 512 GB SSD Expandable~1TB 14.1 FHD IPS Laptop Anti-Glare Ultra Thin Bezel 180° Hinge 3.0x3 USB HDMI SD Card Slot Win 11 Home 1.25KG Silver',
#   'BrowseBook 14.1" FHD IPS Laptop | Best Student & Office Work Laptop | Celeron N4020 | 8GB RAM | 256GB SSD | Windows 11 | 38Wh | 1.3kg | Grey',
#   'Lenovo IdeaPad Slim 3 13th Gen Core i7-13620H 15.3" (38.8cm) WUXGA IPS Laptop (24GB RAM/1TB SSD/Win 11/Office 2024/Backlit/1Yr ADP Free/Top Metal Cover & IR Camera/Grey/1.6Kg),83K100TEIN',
#   'HP Smartchoice Victus, AMD Ryzen 5 8645HS, 6GB RTX 3050, 31 Tops, 16GB DDR5(Upgradeable) 512GB SSD, 144Hz, 300nits, FHD, 15.6"/39.6cm, Win11, M365* Office24, Blue, 2.3kg, fb3009AX, AI Gaming Laptop',
#   'ASUS Vivobook Go 14, AMD Ryzen 3 7320U, 8GB RAM, 512GB SSD, FHD 14", Windows 11, Office Home 2024, Mixed Black, 1.38 kg, E1404FA-NK3325WS, AMD Radeon iGPU, M365 Basic (1Year)*, Thin & Light Laptop',
#   'Lenovo V15 G4 AMD Athlon Silver 7120U Laptop 8GB LPDDR5 Ram, 512 GB SSD PCIe, Windows 11 Lifetime Validity,15.6" FHD Screen, AMD Radeon 610M, Silver, 1 Year Brand Warranty',
#   'HP Victus, 13th Gen Intel Core i7-13620H, 8GB RTX 5060, 24GB DDR5(Upgradeable) 1TB SSD, 144Hz, 300nits, IPS, FHD, 15.6"/39.6cm, Win11, M365* Office 24, Mica Silver, 2.29Kg, fa2308TX, RGB Laptop',
#   'DeII Latitude 5410 InteI Core i5 10th Gen | 8GB RAM | 256GB SSD | 14" FHD | Backlit Keyboard | Sleek & Thin Business Laptop Silver (Certified & Tested)',
#   'ASUS Gaming V16 (2025) 14th Gen,Intel Core 7 240H Gaming Laptop (RTX 4050-6GB/16GB RAM/512GB SSD/Windows 11 Home/16/144Hz/M365*/Office Home 2024, Matte Black,1.95 Kg),V3607VU-RP275WS',
#   'Lenovo Yoga Slim 7 (Smartchoice) Intel Core Ultra 9 185H 14"(35.5cm) WUXGA-OLED Laptop (32GB RAM/1TB SSD/AI PC/Windows 11/Microsoft 365 Basic + Office Home 2024/1Yr ADP Free/Grey/1.39Kg), 83CV00B3IN',
#   'Lenovo Smartchoice Yoga Slim 7 Aura Edition, Intel Core Ultra 7 258V, 47 Tops, Copilot+ AI PC, 32GB RAM, 1TB SSD, 15"(38.86cm), Windows 11, MS Office Home 2024, Grey, 1.53Kg, 83HM004NIN, AI Laptop',
#   'Comfyable Puffy Laptop Sleeve 13 Inch 14 Inch, Quilted Puffer Laptop Carrying Case for Women, Pillow Case Compatible for MacBook Air M4 M3 M2 M1, MacBook Pro 13 Inch 14 Inch, 13 in 14 in Cover, Black',
#   'Comfyable Puffy Laptop Sleeve 13 Inch 14 Inch, Quilted Puffer Laptop Carrying Case for Women, Pillow Case Compatible for MacBook Air M4 M3 M2 M1, MacBook Pro 13 Inch 14 Inch, 13 in 14 in Cover, Black'],
#  'price': ['₹35,990.00',
#   '₹38,999.00',
#   '₹12,090.00',
#   '₹30,990.00',
#   '₹24,490.00',
#   '₹21,590.00',
#   '₹1,14,990.00',
#   '₹1,47,990.00',
#   '₹54,490.00',
#   '₹18,590.00',
#   '₹26,490.00',
#   '₹33,990.00',
#   '₹31,990.00',
#   '₹42,990.00',
#   '₹36,990.00',
#   '₹38,490.00',
#   '₹25,990.00',
#   '₹1,599.00',
#   '₹1,599.00',
#   '₹56,990.00',
#   '₹27,240.00',
#   '₹49,990.00',
#   '₹52,990.00',
#   '₹35,499.00',
#   '₹14,990.00',
#   '₹34,490.00',
#   '₹17,255.00',
#   '₹15,990.00',
#   '₹74,390.00',
#   '₹64,990.00',
#   '₹33,990.00',
#   '₹28,999.00',
#   '₹1,10,990.00',
#   '₹24,299.00',
#   '₹94,990.00',
#   '₹1,14,990.00',
#   '₹1,47,990.00',
#   '₹2,799.00',
#   '₹2,799.00'],
#  'rating': ['3.8 out of 5 stars',
#   '4.3 out of 5 stars',
#   '4.7 out of 5 stars',
#   '3.9 out of 5 stars',
#   '3.4 out of 5 stars',
#   '4.4 out of 5 stars',
#   '4.4 out of 5 stars',
#   '4.2 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.4 out of 5 stars',
#   '4.1 out of 5 stars',
#   '4.1 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.7 out of 5 stars',
#   '3.8 out of 5 stars',
#   '4.1 out of 5 stars',
#   '4.4 out of 5 stars',
#   '4.4 out of 5 stars',
#   '4.4 out of 5 stars',
#   '3.9 out of 5 stars',
#   '4.4 out of 5 stars',
#   '3.6 out of 5 stars',
#   '4.4 out of 5 stars',
#   '3.9 out of 5 stars',
#   '4.4 out of 5 stars',
#   '3.9 out of 5 stars',
#   '4.4 out of 5 stars',
#   '4.4 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.8 out of 5 stars',
#   '4.1 out of 5 stars',
#   '4.4 out of 5 stars',
#   '3.6 out of 5 stars',
#   '1.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.4 out of 5 stars',
#   '4.2 out of 5 stars',
#   '4.4 out of 5 stars',
#   '4.4 out of 5 stars'],
#  'reviews': ['(56)',
#   '(313)',
#   '(60)',
#   '(2,070)',
#   '(818)',
#   '(369)',
#   '(16)',
#   '(48)',
#   '(40)',
#   '(248)',
#   '(10)',
#   '(964)',
#   '(1,992)',
#   '(100)',
#   '(104)',
#   '(964)',
#   '(818)',
#   '(6,220)',
#   '(6,220)',
#   '(766)',
#   '(32)',
#   '(22)',
#   '(70)',
#   '(2,070)',
#   '(437)',
#   '(586)',
#   '(113)',
#   '(60)',
#   '(1)',
#   '(347)',
#   '(210)',
#   '(287)',
#   '(5)',
#   '(1)',
#   '(48)',
#   '(16)',
#   '(48)',
#   '(2,033)',
#   '(2,033)'],
#  'availability': ['In stock',
#   'In stock',
#   '',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'Only 1 left in stock.',
#   '',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'Only 1 left in stock.',
#   'Only 1 left in stock.',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'In stock',
#   'Only 2 left in stock.',
#   'In stock',
#   'In stock',
#   'In stock',
#   'Only 1 left in stock.',
#   'In stock',
#   'In stock']}

# %%
amazon_df
# Out:
#                                                 title        price rating  \
# 0   Lenovo V14 Intel Core i3 13th Gen 14" FHD (192...   ₹35,990.00    3.8
# 1   Lenovo V15 G4 AMD Ryzen 5 7520U 15.6 inch FHD ...   ₹38,999.00    4.3
# 2   BrowseBook 14.1" FHD IPS Laptop | Best Student...   ₹12,090.00    4.7
# 3   acer Aspire Lite, AMD Ryzen 3 5300U Processor,...   ₹30,990.00    3.9
# 4   acer [SmartChoice Aspire 3 Laptop Intel Core C...   ₹24,490.00    3.4
# 5   Primebook 2 Max 2025 (New Launch) | 8GB RAM, 2...   ₹21,590.00    4.4
# 6   Lenovo Yoga Slim 7 (Smartchoice) Intel Core Ul...  ₹114,990.00    4.4
# 7   Lenovo Smartchoice Yoga Slim 7 Aura Edition, I...  ₹147,990.00    4.2
# 8   Lenovo ThinkBook 16, AMD Ryzen 7 7735HS, 16GB ...   ₹54,490.00    4.0
# 9   Primebook 2 Pro 2025 (New Launch) | 8GB RAM, 1...   ₹18,590.00    4.4
# 10  HP 14s Intel Celeron Dual Core N4500 Laptop (8...   ₹26,490.00    4.1
# 11  HP 15s, 12th Gen Intel Core i3-1215U (8GB DDR4...   ₹33,990.00    4.1
# 12  HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD)...   ₹31,990.00    4.0
# 13  Dell 15, AMD Ryzen 5-7530U Processor, 16GB RAM...   ₹42,990.00    4.7
# 14  HP 255 G10 Laptop for Home or Work, 16GB RAM D...   ₹36,990.00    3.8
# 15  HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4...   ₹38,490.00    4.1
# 16  Acer Aspire 3, Intel Core Celeron N4500, 12GB ...   ₹25,990.00    4.4
# 17  Comfyable Laptop Sleeve 13 Inch Precisely Comp...    ₹1,599.00    4.4
# 18  Comfyable Laptop Sleeve 13 Inch Precisely Comp...    ₹1,599.00    4.4
# 19  HP 15, 13th Gen Intel Core i5-1334U (16GB DDR4...   ₹56,990.00    3.9
# 20  Lenovo IdeaPad 1 Intel Celeron N4500, 8GB RAM,...   ₹27,240.00    4.4
# 21  Dell 15, AMD Ryzen 7-7730U, 16GB DDR4, 512GB S...   ₹49,990.00    3.6
# 22  Lenovo ThinkBook 16, AMD Ryzen 7 7735HS, 16GB ...   ₹52,990.00    4.4
# 23  Acer SmartChoice Aspire Lite, AMD Ryzen 5-5625...   ₹35,499.00    3.9
# 24  Primebook 2 Neo 2025 (New Launch) | 6GB RAM, 1...   ₹14,990.00    4.4
# 25  Acer Aspire Lite, Intel Core i3 13th Gen - 130...   ₹34,490.00    3.9
# 26  ULTIMUS APEX Laptop Intel Celeron Dual Core 8 ...   ₹17,255.00    4.4
# 27  BrowseBook 14.1" FHD IPS Laptop | Best Student...   ₹15,990.00    4.4
# 28  Lenovo IdeaPad Slim 3 13th Gen Core i7-13620H ...   ₹74,390.00    5.0
# 29  HP Smartchoice Victus, AMD Ryzen 5 8645HS, 6GB...   ₹64,990.00    3.8
# 30  ASUS Vivobook Go 14, AMD Ryzen 3 7320U, 8GB RA...   ₹33,990.00    4.1
# 31  Lenovo V15 G4 AMD Athlon Silver 7120U Laptop 8...   ₹28,999.00    4.4
# 32  HP Victus, 13th Gen Intel Core i7-13620H, 8GB ...  ₹110,990.00    3.6
# 33  DeII Latitude 5410 InteI Core i5 10th Gen | 8G...   ₹24,299.00    1.0
# 34  ASUS Gaming V16 (2025) 14th Gen,Intel Core 7 2...   ₹94,990.00    4.0
# 35  Lenovo Yoga Slim 7 (Smartchoice) Intel Core Ul...  ₹114,990.00    4.4
# 36  Lenovo Smartchoice Yoga Slim 7 Aura Edition, I...  ₹147,990.00    4.2
# 37  Comfyable Puffy Laptop Sleeve 13 Inch 14 Inch,...    ₹2,799.00    4.4
# 38  Comfyable Puffy Laptop Sleeve 13 Inch 14 Inch,...    ₹2,799.00    4.4
#
#    reviews           availability
# 0     (56)               In stock
# 1    (313)               In stock
# 2     (60)
# 3   (2070)               In stock
# 4    (818)               In stock
# 5    (369)               In stock
# 6     (16)               In stock
# 7     (48)  Only 1 left in stock.
# 8     (40)
# 9    (248)               In stock
# 10    (10)               In stock
# 11   (964)               In stock
# 12  (1992)               In stock
# 13   (100)               In stock
# 14   (104)               In stock
# 15   (964)               In stock
# 16   (818)               In stock
# 17  (6220)  Only 1 left in stock.
# 18  (6220)  Only 1 left in stock.
# 19   (766)               In stock
# 20    (32)               In stock
# 21    (22)               In stock
# 22    (70)               In stock
# 23  (2070)               In stock
# 24   (437)               In stock
# 25   (586)               In stock
# 26   (113)               In stock
# 27    (60)               In stock
# 28     (1)               In stock
# 29   (347)               In stock
# 30   (210)               In stock
# 31   (287)               In stock
# 32     (5)  Only 2 left in stock.
# 33     (1)               In stock
# 34    (48)               In stock
# 35    (16)               In stock
# 36    (48)  Only 1 left in stock.
# 37  (2033)               In stock
# 38  (2033)               In stock

# %%
amazon_df = amazon_df[['title', 'price', 'rating', 'reviews', 'availability']]
amazon_df
# Out:
#                                                 title         price rating  \
# 0   Lenovo V14 Intel Core i3 13th Gen 14" FHD (192...    ₹35,990.00    3.8
# 1   Lenovo V15 G4 AMD Ryzen 5 7520U 15.6 inch FHD ...    ₹38,999.00    4.3
# 2   BrowseBook 14.1" FHD IPS Laptop | Best Student...    ₹12,090.00    4.7
# 3   HP 15, 13th Gen Intel Core i5-1334U (16GB DDR4...    ₹56,990.00    3.9
# 4   DeII Latitude 5410 InteI Core i5 10th Gen | 8G...    ₹24,299.00    1.0
# 5   Primebook 2 Max 2025 (New Launch) | 8GB RAM, 2...    ₹21,590.00    4.4
# 6   Lenovo Yoga Slim 7 (Smartchoice) Intel Core Ul...  ₹1,14,990.00    4.4
# 7   Lenovo Smartchoice Yoga Slim 7 Aura Edition, I...  ₹1,47,990.00    4.2
# 8   Lenovo ThinkBook 16, AMD Ryzen 7 7735HS, 16GB ...    ₹54,490.00    4.0
# 9   Primebook 2 Pro 2025 (New Launch) | 8GB RAM, 1...    ₹18,590.00    4.4
# 10  Comfyable Laptop Sleeve 13 Inch Precisely Comp...     ₹1,599.00    4.4
# 11  Comfyable Laptop Sleeve 13 Inch Precisely Comp...     ₹1,599.00    4.4
# 12  acer [SmartChoice Aspire 3 Laptop Intel Core C...    ₹24,490.00    3.4
# 13  acer Aspire Lite, AMD Ryzen 3 5300U Processor,...    ₹30,990.00    3.9
# 14  Dell 15, AMD Ryzen 5-7530U Processor, 16GB RAM...    ₹42,990.00    4.7
# 15  HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4...    ₹38,490.00    4.1
# 16  HP 14s Intel Celeron Dual Core N4500 Laptop (8...    ₹26,490.00    4.1
# 17  HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD)...    ₹31,990.00    4.0
# 18  ASUS Gaming V16 (2025) 14th Gen,Intel Core 7 2...    ₹94,990.00    4.0
# 19  Lenovo IdeaPad 1 Intel Celeron N4500, 8GB RAM,...    ₹27,240.00    4.4
# 20  HP Smartchoice Victus, AMD Ryzen 5 8645HS, 6GB...    ₹64,990.00    3.8
# 21  Dell 15, 13th Generation Intel Core i5-1334U P...    ₹58,490.00    4.4
# 22  Dell 15, AMD Ryzen 7-7730U, 16GB DDR4, 512GB S...    ₹49,990.00    3.6
# 23  BrowseBook 14.1" FHD IPS Laptop | Best Student...    ₹15,990.00    4.4
# 24  Acer Aspire Lite, Intel Core i3 13th Gen - 130...    ₹34,490.00    3.9
# 25  HP 15s, 12th Gen Intel Core i3-1215U (8GB DDR4...    ₹33,990.00    4.1
# 26  Lenovo IdeaPad Slim 3 13th Gen Core i7-13620H ...    ₹74,390.00    5.0
# 27  Acer Aspire 3, Intel Core Celeron N4500, 12GB ...    ₹25,990.00    4.4
# 28  HP 14s, Intel Celeron N4500 Laptop (8GB DDR4,5...    ₹26,990.00    3.9
# 29  HP 255 G10 Laptop for Home or Work, 16GB RAM D...    ₹36,990.00    3.8
# 30  HP Victus, 13th Gen Intel Core i7-13620H, 8GB ...  ₹1,10,990.00    3.6
# 31  Dell 15 Laptop DC15250-15.6-inch FHD 120Hz Dis...    ₹71,390.00    4.4
# 32  HP 15 Laptop, AMD Ryzen 7 7730U (16GB DDR4,512...    ₹50,990.00    4.0
# 33  ULTIMUS APEX Laptop Intel Celeron Dual Core 8 ...    ₹17,255.00    4.4
# 34  Lenovo IdeaPad Slim 1 AMD Ryzen 5 5500U 15.6" ...    ₹33,639.00    4.4
# 35  Lenovo ThinkBook 16, AMD Ryzen 7 7735HS, 16GB ...    ₹52,990.00    4.4
# 36  Lenovo Smartchoice Yoga Slim 7 Aura Edition, I...  ₹1,47,990.00    4.2
# 37  Comfyable Puffy Laptop Sleeve 13 Inch 14 Inch,...     ₹2,799.00    4.4
# 38  Comfyable Puffy Laptop Sleeve 13 Inch 14 Inch,...     ₹2,799.00    4.4
#
#    reviews           availability
# 0     (56)               In stock
# 1    (313)               In stock
# 2     (60)
# 3    (766)               In stock
# 4      (1)               In stock
# 5    (369)               In stock
# 6     (16)               In stock
# 7     (48)  Only 1 left in stock.
# 8     (40)
# 9    (248)               In stock
# 10  (6220)  Only 1 left in stock.
# 11  (6220)  Only 1 left in stock.
# 12   (818)               In stock
# 13  (2070)               In stock
# 14   (100)               In stock
# 15   (964)               In stock
# 16    (10)               In stock
# 17  (1992)               In stock
# 18    (48)               In stock
# 19    (32)               In stock
# 20   (347)               In stock
# 21   (169)               In stock
# 22    (22)               In stock
# 23    (60)               In stock
# 24   (586)               In stock
# 25   (964)               In stock
# 26     (1)               In stock
# 27   (818)               In stock
# 28   (188)               In stock
# 29   (104)               In stock
# 30     (5)  Only 2 left in stock.
# 31   (492)               In stock
# 32    (78)               In stock
# 33   (113)               In stock
# 34  (2493)               In stock
# 35    (70)               In stock
# 36    (48)  Only 1 left in stock.
# 37  (2033)               In stock
# 38  (2033)               In stock

# %%
print(amazon_df.head())
# Out:
#                                                title       price rating  \
# 0  Lenovo V14 Intel Core i3 13th Gen 14" FHD (192...  ₹35,990.00    3.8
# 1  Lenovo V15 G4 AMD Ryzen 5 7520U 15.6 inch FHD ...  ₹38,999.00    4.3
# 2  BrowseBook 14.1" FHD IPS Laptop | Best Student...  ₹12,090.00    4.7
# 3  acer Aspire Lite, AMD Ryzen 3 5300U Processor,...  ₹30,990.00    3.9
# 4  HP 14s Intel Celeron Dual Core N4500 Laptop (8...  ₹26,490.00    4.1
#
#   reviews availability
# 0    (56)     In stock
# 1   (313)     In stock
# 2    (60)
# 3  (2070)     In stock
# 4    (10)     In stock
